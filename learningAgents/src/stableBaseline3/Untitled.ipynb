# %%
# !pip install pytorch
# !pip install stable-baselines3[extra]
# !pip install gym[box2d]
# Out:
# ...
#   Using cached pytorch-1.0.2.tar.gz (689 bytes)
# ...
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ...
#     Running setup.py install for pytorch: started
#     Running setup.py install for pytorch: finished with status 'error'
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\sjaha\documents\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\sjaha\documents\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yping-extensions (c:\users\sjaha\documents\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\sjaha\documents\anaconda\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import gym
from sta
