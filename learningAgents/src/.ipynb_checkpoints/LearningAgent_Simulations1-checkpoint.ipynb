# %%
from learningAgents import ReinforceAlgorithm
from environmentModel import Model, AdversaryModes
from NeuralNetwork import NeuralNetwork
import torch
import torch.nn as nn
from torch.distributions import Categorical

# %%
adversaryProbs=torch.zeros(len(AdversaryModes))
adversaryProbs[0]=1
game = Model(totalDemand = 400, 
               tupleCosts = (57, 71),
              totalStages = 2, adversaryProbs=adversaryProbs)

# %%
neuralNet=NeuralNetwork(lr = 0.000001, num_input= 2, num_actions=20, nn_dim = 100)
algorithm = ReinforceAlgorithm(game, neuralNet, numberBatches=100_000, numberEpiPerBatch=100, discountFactor =0.99, creditFactor = 0.9, numberIterations = 1)

# %%
algorithm.solver()
# Out:
# tensor([0.0547, 0.0499, 0.0487, 0.0540, 0.0599, 0.0416, 0.0578, 0.0493, 0.0524,
#         0.0467, 0.0634, 0.0466, 0.0429, 0.0486, 0.0448, 0.0550, 0.0461, 0.0435,
#         0.0494, 0.0445], grad_fn=<SoftmaxBackward0>)
# tensor([0.0586, 0.0455, 0.0532, 0.0506, 0.0621, 0.0381, 0.0572, 0.0511, 0.0491,
#         0.0429, 0.0606, 0.0440, 0.0429, 0.0539, 0.0459, 0.0577, 0.0481, 0.0436,
#         0.0505, 0.0443], grad_fn=<SoftmaxBackward0>)
# 0 -935.4962158203125 -92.93757375
# tensor([0.0521, 0.0491, 0.0480, 0.0534, 0.0595, 0.0417, 0.0564, 0.0491, 0.0523,
#         0.0468, 0.0622, 0.0469, 0.0430, 0.0501, 0.0449, 0.0563, 0.0464, 0.0443,
#         0.0511, 0.0464], grad_fn=<SoftmaxBackward0>)
# tensor([0.0653, 0.0489, 0.0575, 0.0527, 0.0647, 0.0392, 0.0623, 0.0534, 0.0479,
#         0.0443, 0.0595, 0.0432, 0.0418, 0.0509, 0.0442, 0.0545, 0.0448, 0.0402,
#         0.0449, 0.0398], grad_fn=<SoftmaxBackward0>)
# 5000 -909.762451171875 -90.30013625000005
# tensor([0.0497, 0.0477, 0.0474, 0.0529, 0.0591, 0.0414, 0.0554, 0.0485, 0.0526,
#         0.0469, 0.0619, 0.0479, 0.0433, 0.0513, 0.0448, 0.0569, 0.0469, 0.0446,
#         0.0527, 0.0483], grad_fn=<SoftmaxBackward0>)
# tensor([0.0716, 0.0518, 0.0626, 0.0548, 0.0669, 0.0399, 0.0662, 0.0555, 0.0473,
#         0.0453, 0.0589, 0.0423, 0.0408, 0.0482, 0.0423, 0.0509, 0.0414, 0.0368,
#         0.0401, 0.0364], grad_fn=<SoftmaxBackward0>)
# 10000 -847.9661254882812 -84.22926249999998
# tensor([0.0473, 0.0462, 0.0467, 0.0522, 0.0588, 0.0410, 0.0542, 0.0479, 0.0524,
#         0.0472, 0.0617, 0.0489, 0.0437, 0.0522, 0.0446, 0.0574, 0.0473, 0.0452,
#         0.0547, 0.0504], grad_fn=<SoftmaxBackward0>)
# tensor([0.0805, 0.0545, 0.0686, 0.0571, 0.0707, 0.0402, 0.0699, 0.0578, 0.0466,
#         0.0459, 0.0577, 0.0405, 0.0384, 0.0457, 0.0397, 0.0471, 0.0378, 0.0331,
#         0.0354, 0.0329], grad_fn=<SoftmaxBackward0>)
# 15000 -893.1887817382812 -88.3672075
# tensor([0.0447, 0.0444, 0.0457, 0.0514, 0.0583, 0.0403, 0.0524, 0.0472, 0.0520,
#         0.0471, 0.0619, 0.0501, 0.0442, 0.0531, 0.0445, 0.0583, 0.0480, 0.0461,
#         0.0572, 0.0530], grad_fn=<SoftmaxBackward0>)
# tensor([0.0901, 0.0569, 0.0752, 0.0599, 0.0749, 0.0399, 0.0731, 0.0602, 0.0458,
#         0.0461, 0.0567, 0.0389, 0.0364, 0.0430, 0.0366, 0.0430, 0.0338, 0.0294,
#         0.0310, 0.0292], grad_fn=<SoftmaxBackward0>)
# 20000 -856.405029296875 -84.83072374999999
# tensor([0.0414, 0.0418, 0.0440, 0.0502, 0.0573, 0.0391, 0.0502, 0.0459, 0.0513,
#         0.0465, 0.0625, 0.0515, 0.0450, 0.0543, 0.0447, 0.0602, 0.0494, 0.0475,
#         0.0605, 0.0565], grad_fn=<SoftmaxBackward0>)
# tensor([0.1000, 0.0586, 0.0811, 0.0629, 0.0799, 0.0393, 0.0762, 0.0616, 0.0445,
#         0.0460, 0.0563, 0.0369, 0.0343, 0.0407, 0.0336, 0.0394, 0.0304, 0.0257,
#         0.0269, 0.0259], grad_fn=<SoftmaxBackward0>)
# 25000 -831.0794677734375 -82.21926875000003
# tensor([0.0379, 0.0389, 0.0417, 0.0487, 0.0558, 0.0377, 0.0475, 0.0444, 0.0502,
#         0.0455, 0.0631, 0.0529, 0.0458, 0.0556, 0.0450, 0.0628, 0.0517, 0.0493,
#         0.0648, 0.0610], grad_fn=<SoftmaxBackward0>)
# tensor([0.1189, 0.0607, 0.0887, 0.0664, 0.0883, 0.0386, 0.0809, 0.0623, 0.0423,
#         0.0452, 0.0541, 0.0333, 0.0298, 0.0369, 0.0296, 0.0349, 0.0257, 0.0207,
#         0.0216, 0.0212], grad_fn=<SoftmaxBackward0>)
# 30000 -809.3400268554688 -80.01767374999999
# tensor([0.0342, 0.0356, 0.0391, 0.0466, 0.0537, 0.0361, 0.0444, 0.0426, 0.0486,
#         0.0442, 0.0635, 0.0541, 0.0467, 0.0570, 0.0453, 0.0658, 0.0544, 0.0517,
#         0.0700, 0.0666], grad_fn=<SoftmaxBackward0>)
# tensor([0.1337, 0.0612, 0.0948, 0.0694, 0.0947, 0.0373, 0.0836, 0.0632, 0.0403,
#         0.0447, 0.0534, 0.0308, 0.0273, 0.0342, 0.0261, 0.0310, 0.0220, 0.0171,
#         0.0177, 0.0177], grad_fn=<SoftmaxBackward0>)
# 35000 -785.3878173828125 -77.3867425
# tensor([0.0305, 0.0323, 0.0362, 0.0442, 0.0512, 0.0342, 0.0411, 0.0406, 0.0465,
#         0.0425, 0.0637, 0.0549, 0.0476, 0.0581, 0.0456, 0.0691, 0.0576, 0.0546,
#         0.0762, 0.0734], grad_fn=<SoftmaxBackward0>)
# tensor([0.1578, 0.0612, 0.1010, 0.0724, 0.1034, 0.0356, 0.0876, 0.0634, 0.0372,
#         0.0436, 0.0511, 0.0267, 0.0230, 0.0307, 0.0219, 0.0262, 0.0175, 0.0128,
#         0.0132, 0.0134], grad_fn=<SoftmaxBackward0>)
# 40000 -754.1024780273438 -74.21362375000002
# tensor([0.0270, 0.0290, 0.0334, 0.0416, 0.0481, 0.0320, 0.0378, 0.0381, 0.0440,
#         0.0401, 0.0638, 0.0552, 0.0483, 0.0587, 0.0456, 0.0724, 0.0613, 0.0581,
#         0.0840, 0.0816], grad_fn=<SoftmaxBackward0>)
# tensor([0.1708, 0.0595, 0.1039, 0.0744, 0.1089, 0.0337, 0.0888, 0.0638, 0.0350,
#         0.0432, 0.0513, 0.0250, 0.0214, 0.0293, 0.0195, 0.0236, 0.0151, 0.0106,
#         0.0109, 0.0113], grad_fn=<SoftmaxBackward0>)
# 45000 -758.7642822265625 -74.58744500000002
# tensor([0.0236, 0.0260, 0.0306, 0.0390, 0.0447, 0.0296, 0.0346, 0.0354, 0.0412,
#         0.0376, 0.0637, 0.0552, 0.0487, 0.0586, 0.0452, 0.0752, 0.0649, 0.0619,
#         0.0932, 0.0911], grad_fn=<SoftmaxBackward0>)
# tensor([0.2017, 0.0577, 0.1080, 0.0761, 0.1165, 0.0309, 0.0910, 0.0625, 0.0313,
#         0.0411, 0.0483, 0.0210, 0.0175, 0.0261, 0.0159, 0.0196, 0.0116, 0.0075,
#         0.0076, 0.0080], grad_fn=<SoftmaxBackward0>)
# 50000 -779.45849609375 -75.04645375000001
# tensor([0.0207, 0.0231, 0.0282, 0.0364, 0.0415, 0.0274, 0.0314, 0.0327, 0.0383,
#         0.0352, 0.0632, 0.0550, 0.0488, 0.0582, 0.0444, 0.0773, 0.0682, 0.0658,
#         0.1027, 0.1016], grad_fn=<SoftmaxBackward0>)
# tensor([0.2385, 0.0544, 0.1101, 0.0765, 0.1237, 0.0275, 0.0921, 0.0598, 0.0272,
#         0.0386, 0.0445, 0.0171, 0.0139, 0.0229, 0.0127, 0.0160, 0.0087, 0.0051,
#         0.0051, 0.0055], grad_fn=<SoftmaxBackward0>)
# 55000 -736.89599609375 -71.20017625000003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qp/vv6_63sd0n954kctm_7hhrhh0000gn/T/ipykernel_3992/784786145.py in <module>
# ----> 1 algorithm.solver()
#
# ~/Documents/GitHub/EquiLearn/learningAgents/src/learningAgents.py in solver(self)
#      88                         state, reward, done = self.env.step(prevState, action.item())
#      89                         reward = reward * discount
# ---> 90                         normState = torch.tensor([  0.0000, 0.0000])
#      91                         normState[0] = state[0]/(self.env.T - 1)
#      92                         normState[1] = 10 * (state[1]/(self.env.totalDemand)) - 5
#
# KeyboardInterrupt:

# %%
import pandas as pd
profits = pd.DataFrame(game.profit).T
prices = pd.DataFrame(game.prices).T
demandPotential = pd.DataFrame(game.demandPotential).T
learning = pd.DataFrame(algorithm.returns.mean(axis = 0),columns=['entry'])

# %%
learning.plot()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
learning = learning.to_numpy()

# %%
learning_2 = [0]*55000
for i in range(len(learning_2)):
    learning_2[i] = learning[i][0]

# %%
plt.plot(learning_2)
plt.show()

# %%
avg_learning = np.convolve(learning_2, np.ones(1000)/1000, mode = 'valid')

# %%
plt.plot(avg_learning)
plt.show()
