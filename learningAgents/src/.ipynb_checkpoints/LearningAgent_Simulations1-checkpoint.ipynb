# %%
from learningAgents import ReinforceAlgorithm
from environmentModel import Model, AdversaryModes
from NeuralNetwork import NeuralNetwork
import torch
import torch.nn as nn
from torch.distributions import Categorical
import time
import matplotlib.pyplot as plt

# %%
adversaryProbs=torch.zeros(len(AdversaryModes))
adversaryProbs[0]=1
game = Model(totalDemand = 400, 
               tupleCosts = (57, 71),
              totalStages = 25, adversaryProbs=adversaryProbs)

# %%
st = time.time()
neuralNet=NeuralNetwork(lr = 0.0001, num_input= 2, num_actions=50, nn_dim = 150)
algorithm = ReinforceAlgorithm(game, neuralNet, numberBatches=21, numberEpiPerBatch=1, discountFactor =1, creditFactor = 1, numberIterations = 1)
result = algorithm.solver()
ft = time.time()
print(ft - st)
# Out:
# tensor([0.0237, 0.0197, 0.0235, 0.0193, 0.0218, 0.0196, 0.0210, 0.0207, 0.0231,
#         0.0231, 0.0173, 0.0227, 0.0197, 0.0174, 0.0213, 0.0227, 0.0160, 0.0194,
#         0.0178, 0.0158, 0.0186, 0.0150, 0.0166, 0.0183, 0.0148, 0.0225, 0.0217,
#         0.0175, 0.0196, 0.0181, 0.0280, 0.0165, 0.0233, 0.0225, 0.0219, 0.0212,
#         0.0210, 0.0199, 0.0199, 0.0167, 0.0217, 0.0153, 0.0210, 0.0187, 0.0171,
#         0.0225, 0.0219, 0.0216, 0.0227, 0.0186], grad_fn=<SoftmaxBackward0>)
# tensor([0.0230, 0.0197, 0.0228, 0.0182, 0.0228, 0.0201, 0.0207, 0.0202, 0.0222,
#         0.0223, 0.0171, 0.0223, 0.0204, 0.0171, 0.0210, 0.0216, 0.0168, 0.0212,
#         0.0185, 0.0162, 0.0191, 0.0154, 0.0169, 0.0180, 0.0154, 0.0217, 0.0213,
#         0.0181, 0.0205, 0.0189, 0.0263, 0.0172, 0.0232, 0.0223, 0.0207, 0.0211,
#         0.0207, 0.0203, 0.0200, 0.0179, 0.0219, 0.0170, 0.0215, 0.0188, 0.0165,
#         0.0218, 0.0218, 0.0212, 0.0211, 0.0189], grad_fn=<SoftmaxBackward0>)
# tensor([0.0223, 0.0198, 0.0219, 0.0179, 0.0241, 0.0201, 0.0202, 0.0200, 0.0211,
#         0.0221, 0.0180, 0.0209, 0.0203, 0.0172, 0.0212, 0.0199, 0.0176, 0.0220,
#         0.0191, 0.0165, 0.0198, 0.0162, 0.0174, 0.0183, 0.0164, 0.0206, 0.0214,
#         0.0179, 0.0215, 0.0191, 0.0236, 0.0184, 0.0239, 0.0228, 0.0197, 0.0209,
#         0.0213, 0.0197, 0.0193, 0.0197, 0.0211, 0.0192, 0.0221, 0.0190, 0.0165,
#         0.0207, 0.0222, 0.0211, 0.0194, 0.0183], grad_fn=<SoftmaxBackward0>)
# tensor([0.0215, 0.0193, 0.0203, 0.0163, 0.0274, 0.0204, 0.0196, 0.0196, 0.0195,
#         0.0225, 0.0184, 0.0224, 0.0205, 0.0169, 0.0219, 0.0197, 0.0176, 0.0240,
#         0.0208, 0.0155, 0.0201, 0.0166, 0.0170, 0.0173, 0.0158, 0.0219, 0.0200,
#         0.0197, 0.0162, 0.0201, 0.0164, 0.0175, 0.0186, 0.0161, 0.0208, 0.0212,
#         0.0179, 0.0217, 0.0191, 0.0240, 0.0184, 0.0235, 0.0222, 0.0194, 0.0204,
#         0.0211, 0.0202, 0.0195, 0.0192, 0.0210, 0.0194, 0.0221, 0.0189, 0.0166,
#         0.0211, 0.0219, 0.0213, 0.0190, 0.0187], grad_fn=<SoftmaxBackward0>)
# tensor([0.0211, 0.0191, 0.0203, 0.0164, 0.0273, 0.0206, 0.0192, 0.0199, 0.0192,
#         0.0222, 0.0183, 0.0221, 0.0203, 0.0170, 0.0217, 0.0193, 0.0172, 0.0235,
#         0.0217, 0.0154, 0.0208, 0.0173, 0.0173, 0.0178, 0.0157, 0.0221, 0.0201,
#         0.0175, 0.0229, 0.0186, 0.0231, 0.0176, 0.0242, 0.0231, 0.0187, 0.0210,
#         0.0236, 0.0209, 0.0201, 0.0200, 0.0209, 0.0219, 0.0208, 0.0184, 0.0158,
#         0.0211, 0.0228, 0.0204, 0.0164, 0.0175], grad_fn=<SoftmaxBackward0>)
# tensor([0.0199, 0.0194, 0.0193, 0.0172, 0.0282, 0.0206, 0.0188, 0.0198, 0.0183,
#         0.0201, 0.0191, 0.0210, 0.0196, 0.0171, 0.0215, 0.0181, 0.0182, 0.0227,
#         0.0214, 0.0154, 0.0209, 0.0178, 0.0173, 0.0178, 0.0167, 0.0208, 0.0199,
#         0.0174, 0.0237, 0.0171, 0.0219, 0.0187, 0.0249, 0.0246, 0.0191, 0.0226,
#         0.0252, 0.0197, 0.0200, 0.0216, 0.0203, 0.0248, 0.0199, 0.0183, 0.0161,
#         0.0205, 0.0240, 0.0205, 0.0156, 0.0168], grad_fn=<SoftmaxBackward0>)
# Gradient Descent 0.004970073699951172
# Gradient Descent 0.00445103645324707
# Gradient Descent 0.004611015319824219
# Gradient Descent 0.0049898624420166016
# Gradient Descent 0.0056629180908203125
# Gradient Descent 0.005186796188354492
# Gradient Descent 0.005517005920410156
# Gradient Descent 0.005125761032104492
# Gradient Descent 0.004758119583129883
# Gradient Descent 0.0044782161712646484
# 0.4063549041748047

# %%
if result[3] > 0.9:
    print(result[1], result[2], result[3])
else:
    print("Not yet converged", result[3])
plt.plot(result[0][0])
plt.show()
print("Best Payoff is ", result[5])
print("Best Actions are ", result[4])
# Out:
# Not yet converged 3.226287905041578e-43
# Best Payoff is  170597.515625
# Best Actions are  [47 14 42  3  5 44 44 23 38 27 37 49 49 42 21 25 28 18 20 30 49 39 32 28
#  32]

# %%
import pandas as pd
learning = pd.DataFrame(algorithm.returns.mean(axis = 0),columns=['entry'])

# %%
learning.plot()
# Out:
# <AxesSubplot:>

# %%
learning.max()
# Out:
# entry    170597.515625
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
learning = learning.to_numpy()

# %%
learning_2 = [0]*len(learning)
for i in range(len(learning_2)):
    learning_2[i] = learning[i][0]

# %%
plt.plot(learning_2)
plt.show()

# %%
# avg_learning = np.convolve(learning_2, np.ones(1000)/1000, mode = 'valid')

# %%
# plt.plot(avg_learning)
# plt.show()
