# %%
from learningAgents import ReinforceAlgorithm
from environmentModel import Model, AdversaryModes
from NeuralNetwork import NeuralNetwork
import torch
import torch.nn as nn
from torch.distributions import Categorical

# %%
adversaryProbs=torch.zeros(len(AdversaryModes))
adversaryProbs[0]=1
game = Model(totalDemand = 400, 
               tupleCosts = (57, 71),
              totalStages = 2, adversaryProbs=adversaryProbs)

# %%
neuralNet=NeuralNetwork(lr = 0.000001, num_input= 2, num_actions=30, nn_dim = 100)
algorithm = ReinforceAlgorithm(game, neuralNet, numberBatches=10000, numberEpiPerBatch=100, discountFactor =0.99, creditFactor = 0.9, numberIterations = 1)

# %%
algorithm.solver()
# Out:
# tensor([0.0341, 0.0305, 0.0340, 0.0358, 0.0344, 0.0318, 0.0337, 0.0350, 0.0318,
#         0.0310, 0.0428, 0.0337, 0.0359, 0.0322, 0.0287, 0.0337, 0.0277, 0.0380,
#         0.0323, 0.0296, 0.0321, 0.0315, 0.0331, 0.0353, 0.0348, 0.0300, 0.0342,
#         0.0372, 0.0330, 0.0323], grad_fn=<SoftmaxBackward0>)
# tensor([0.0358, 0.0319, 0.0332, 0.0359, 0.0335, 0.0333, 0.0356, 0.0359, 0.0316,
#         0.0324, 0.0415, 0.0323, 0.0354, 0.0338, 0.0276, 0.0354, 0.0314, 0.0372,
#         0.0299, 0.0312, 0.0307, 0.0332, 0.0294, 0.0374, 0.0315, 0.0332, 0.0330,
#         0.0332, 0.0328, 0.0310], grad_fn=<SoftmaxBackward0>)
# 0 -1165.33447265625 -115.78427500000001
# tensor([0.0338, 0.0304, 0.0336, 0.0355, 0.0339, 0.0320, 0.0333, 0.0349, 0.0316,
#         0.0309, 0.0428, 0.0335, 0.0357, 0.0321, 0.0287, 0.0340, 0.0279, 0.0377,
#         0.0322, 0.0298, 0.0322, 0.0317, 0.0335, 0.0358, 0.0349, 0.0304, 0.0340,
#         0.0374, 0.0334, 0.0325], grad_fn=<SoftmaxBackward0>)
# tensor([0.0370, 0.0335, 0.0348, 0.0379, 0.0345, 0.0344, 0.0362, 0.0386, 0.0333,
#         0.0335, 0.0407, 0.0327, 0.0363, 0.0337, 0.0278, 0.0356, 0.0310, 0.0368,
#         0.0294, 0.0304, 0.0302, 0.0326, 0.0282, 0.0357, 0.0311, 0.0318, 0.0311,
#         0.0312, 0.0307, 0.0292], grad_fn=<SoftmaxBackward0>)
# 5000 -1221.292236328125 -121.14515625000004

# %%
import pandas as pd
profits = pd.DataFrame(game.profit).T
prices = pd.DataFrame(game.prices).T
demandPotential = pd.DataFrame(game.demandPotential).T
learning = pd.DataFrame(algorithm.returns.mean(axis = 0),columns=['entry'])

# %%
learning.plot()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
learning = learning.to_numpy()

# %%
learning_2 = [0]*len(learning)
for i in range(len(learning_2)):
    learning_2[i] = learning[i][0]

# %%
plt.plot(learning_2)
plt.show()

# %%
avg_learning = np.convolve(learning_2, np.ones(1000)/1000, mode = 'valid')

# %%
plt.plot(avg_learning)
plt.show()
