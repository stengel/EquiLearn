# %%
from stable_baselines3 import PPO, DQN
import model
import globals as gl
import classes as cl

# %%
gl.initialize()

# %%
lrs=[0.0001, 0.0003, 0.0005, 0.0007, 0.0009]

# %%
costs=[gl.LOW_COST, gl.HIGH_COST]
adv_mixed_strategy = cl.MixedStrategy(strategiesList=[cl.Strategy(
        cl.StrategyType.static, NNorFunc=cl.myopic, name="myopic")], probablitiesArray=[1])
for lr in lrs:
    for _ in range(3):
        model.train_agent(costs=costs, adv_mixed_strategy=adv_mixed_strategy, model= PPO, model_name="PPO", timesteps= 3, num_timesteps=2, lr=lr)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\sjaha\Documents\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\sjaha\Documents\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Logging to logs\PPO-1690916826\PPO-1690916826_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.5     |
# | time/              |          |
# |    fps             | 424      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916826\PPO-1690916826_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1559     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916835\PPO-1690916835_0
# C:\Users\sjaha\Documents\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1464     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916835\PPO-1690916835_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1542     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916841\PPO-1690916841_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1421     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916841\PPO-1690916841_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1456     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916848\PPO-1690916848_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1442     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916848\PPO-1690916848_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1474     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916854\PPO-1690916854_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 1185     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916854\PPO-1690916854_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 1456     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916861\PPO-1690916861_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1500     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916861\PPO-1690916861_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1478     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916867\PPO-1690916867_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1472     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916867\PPO-1690916867_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1472     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916873\PPO-1690916873_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1429     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916873\PPO-1690916873_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 1328     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916880\PPO-1690916880_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1343     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916880\PPO-1690916880_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1264     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916887\PPO-1690916887_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1164     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916887\PPO-1690916887_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1011     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916895\PPO-1690916895_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 789      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916895\PPO-1690916895_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1207     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916904\PPO-1690916904_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 1067     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916904\PPO-1690916904_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 1127     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916912\PPO-1690916912_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1326     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916912\PPO-1690916912_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1184     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916919\PPO-1690916919_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1277     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916919\PPO-1690916919_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    fps             | 1305     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO-1690916926\PPO-1690916926_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1339     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to logs\PPO-1690916926\PPO-1690916926_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    fps             | 1560     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
